# %%
from google.colab import drive
drive.mount('/content/drive') #Google Hesabı Bağlanır
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tqdm import tqdm
import tensorflow as tf
from keras.models import Model
from keras.preprocessing import image
from keras.layers import Flatten
from keras.preprocessing import image
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D

# %%
image_types=['real','fake']
data_dir = 'Data2/'
train_dir = os.path.join(data_dir)

train_data = []
for image_id, sp in enumerate(image_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), image_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'ImageID','Image Type'])
SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

X_train_item = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train_item[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train_item / 255.
print('Train Shape: {}'.format(X_Train.shape))

Y_train = train['ImageID'].values
Y_train = to_categorical(Y_train)
# Out:
# 1709it [00:18, 94.72it/s]
# Train Shape: (1709, 224, 224, 3)

# %%
# !pip install keras-applications
# Out:
# Requirement already satisfied: keras-applications in c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages (1.0.8)
# Requirement already satisfied: h5py in c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages (from keras-applications) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages (from keras-applications) (1.21.6)
# Requirement already satisfied: six in c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages (from h5py->keras-applications) (1.16.0)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\alial\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\alial\anaconda3\envs\dataaipf\lib\site-packages)

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=227,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
from tensorflow.keras import backend as K
#from keras.applications.imagenet_utils import _obtain_input_shape
from keras_applications.imagenet_utils import _obtain_input_shape
#from tensorflow.keras.models import Model


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout

from tensorflow.keras.layers import Activation, Add, Concatenate, GlobalAveragePooling2D,GlobalMaxPooling2D, Input, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, Lambda

from tensorflow.keras.layers import DepthwiseConv2D
import numpy as np
import numpy as np

from tensorflow.python.keras import backend as K

from tensorflow.python.util import nest
from tensorflow.python.util.tf_export import keras_export

def get_source_inputs(tensor, layer=None, node_index=None):

  if not hasattr(tensor, '_keras_history'):
    return tensor

  if layer is None or node_index:
    layer, node_index, _ = tensor._keras_history
  if not layer._inbound_nodes:
    return [tensor]
  else:
    node = layer._inbound_nodes[node_index]
    if not node.inbound_layers:
      # Reached an Input layer, stop recursion.
      return nest.flatten(node.input_tensors)
    else:
      source_tensors = []
      for layer, node_index, _, tensor in node.iterate_inbound():
        previous_sources = get_source_inputs(tensor, layer, node_index)
        # Avoid input redundancy.
        for x in previous_sources:
          if x not in source_tensors:
            source_tensors.append(x)
      return source_tensors

def ShuffleNet(include_top=True, input_tensor=None, scale_factor=1.0, pooling='max',weights = None,
               input_shape=(224,224,3), groups=1, load_model=None, num_shuffle_units=[3, 7, 3],
               bottleneck_ratio=0.25, classes=1000):

    if K.backend() != 'tensorflow':
        raise RuntimeError('Only TensorFlow backend is currently supported, '
                           'as other backends do not support ')

    name = "ShuffleNet_%.2gX_g%d_br_%.2g_%s" % (scale_factor, groups, bottleneck_ratio, "".join([str(x) for x in num_shuffle_units]))

    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                      require_flatten=include_top)


    out_dim_stage_two = {1: 144, 2: 200, 3: 240, 4: 272, 8: 384}
    if groups not in out_dim_stage_two:
        raise ValueError("Invalid number of groups.")

    if pooling not in ['max','avg']:
        raise ValueError("Invalid value for pooling.")

    if not (float(scale_factor) * 4).is_integer():
        raise ValueError("Invalid value for scale_factor. Should be x over 4.")

    exp = np.insert(np.arange(0, len(num_shuffle_units), dtype=np.float32), 0, 0)
    out_channels_in_stage = 2 ** exp
    out_channels_in_stage *= out_dim_stage_two[groups]  # calculate output channels for each stage
    out_channels_in_stage[0] = 24  # first stage has always 24 output channels
    out_channels_in_stage *= scale_factor
    out_channels_in_stage = out_channels_in_stage.astype(int)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    # create shufflenet architecture
    x = Conv2D(filters=out_channels_in_stage[0], kernel_size=(3, 3), padding='same',
               use_bias=False, strides=(2, 2), activation="relu", name="conv1")(img_input)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same', name="maxpool1")(x)

    # create stages containing shufflenet units beginning at stage 2
    for stage in range(0, len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = _block(x, out_channels_in_stage, repeat=repeat,
                   bottleneck_ratio=bottleneck_ratio,
                   groups=groups, stage=stage + 2)

    if pooling == 'avg':
        x = GlobalAveragePooling2D(name="global_pool")(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name="global_pool")(x)

    if include_top:
        x = Dense(units=classes, name="fc")(x)
        x = Activation('softmax', name='softmax')(x)


    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs=inputs, outputs=x, name=name)

    if load_model is not None:
        model.load_weights('', by_name=True)

    return model


def _block(x, channel_map, bottleneck_ratio, repeat=1, groups=1, stage=1):

    x = _shuffle_unit(x, in_channels=channel_map[stage - 2],
                      out_channels=channel_map[stage - 1], strides=2,
                      groups=groups, bottleneck_ratio=bottleneck_ratio,
                      stage=stage, block=1)

    for i in range(1, repeat + 1):
        x = _shuffle_unit(x, in_channels=channel_map[stage - 1],
                          out_channels=channel_map[stage - 1], strides=1,
                          groups=groups, bottleneck_ratio=bottleneck_ratio,
                          stage=stage, block=(i + 1))

    return x


def _shuffle_unit(inputs, in_channels, out_channels, groups, bottleneck_ratio, strides=2, stage=1, block=1):

    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        bn_axis = 1

    prefix = 'stage%d/block%d' % (stage, block)

    #if strides >= 2:
        #out_channels -= in_channels

    # default: 1/4 of the output channel of a ShuffleNet Unit
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    groups = (1 if stage == 2 and block == 1 else groups)

    x = _group_conv(inputs, in_channels, out_channels=bottleneck_channels,
                    groups=(1 if stage == 2 and block == 1 else groups),
                    name='%s/1x1_gconv_1' % prefix)
    x = BatchNormalization(axis=bn_axis, name='%s/bn_gconv_1' % prefix)(x)
    x = Activation('relu', name='%s/relu_gconv_1' % prefix)(x)

    x = Lambda(channel_shuffle, arguments={'groups': groups}, name='%s/channel_shuffle' % prefix)(x)
    x = DepthwiseConv2D(kernel_size=(3, 3), padding="same", use_bias=False,
                        strides=strides, name='%s/1x1_dwconv_1' % prefix)(x)
    x = BatchNormalization(axis=bn_axis, name='%s/bn_dwconv_1' % prefix)(x)

    x = _group_conv(x, bottleneck_channels, out_channels=out_channels if strides == 1 else out_channels - in_channels,
                    groups=groups, name='%s/1x1_gconv_2' % prefix)
    x = BatchNormalization(axis=bn_axis, name='%s/bn_gconv_2' % prefix)(x)

    if strides < 2:
        ret = Add(name='%s/add' % prefix)([x, inputs])
    else:
        avg = AveragePooling2D(pool_size=3, strides=2, padding='same', name='%s/avg_pool' % prefix)(inputs)
        ret = Concatenate(bn_axis, name='%s/concat' % prefix)([x, avg])

    ret = Activation('relu', name='%s/relu_out' % prefix)(ret)

    return ret


def _group_conv(x, in_channels, out_channels, groups, kernel=1, stride=1, name=''):

    if groups == 1:
        return Conv2D(filters=out_channels, kernel_size=kernel, padding='same',
                      use_bias=False, strides=stride, name=name)(x)

    # number of intput channels per group
    ig = in_channels // groups
    group_list = []

    assert out_channels % groups == 0

    for i in range(groups):
        offset = i * ig
        group = Lambda(lambda z: z[:, :, :, offset: offset + ig], name='%s/g%d_slice' % (name, i))(x)
        group_list.append(Conv2D(int(0.5 + out_channels / groups), kernel_size=kernel, strides=stride,
                                 use_bias=False, padding='same', name='%s_/g%d' % (name, i))(group))
    return Concatenate(name='%s/concat' % name)(group_list)


def channel_shuffle(x, groups):

    height, width, in_channels = x.shape.as_list()[1:]
    channels_per_group = in_channels // groups

    x = K.reshape(x, [-1, height, width, groups, channels_per_group])
    x = K.permute_dimensions(x, (0, 1, 2, 4, 3))  # transpose
    x = K.reshape(x, [-1, height, width, in_channels])

    return x

# %%
from tensorflow.keras.layers import Concatenate, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

# base modelleri oluşturuyoruz
base_model1 = SqueezeNet(input_shape=(224, 224, 3))
base_model2 = ShuffleNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3), classes=2)

# layerları eğitilebilir olarak ayarlıyoruz
for layer in base_model1.layers:
    layer.trainable = True
for layer in base_model2.layers:
    layer.trainable = True

# iki modelde aynı isimli layer lar var hata veriyordu böylece layer isimlerini değiştirip çözdük
for layer in base_model1.layers:
    layer._name = 'squeezenet_' + layer.name
for layer in base_model2.layers:
    layer._name = 'shufflenet_' + layer.name

# %%
# 2 modelin çıktısını birleştirme
concatenated_output = Concatenate()([base_model1.output, base_model2.output])

# özellik haritalarını düzleştirir
flatten_layer = Flatten()(concatenated_output)

# overfittingi engellemek için kullanılır ağın genelleme yeteneğini arttırır
dropout_layer = Dropout(0.8)(flatten_layer)

#tam bağlı bir katman oluşturur
output_layer = Dense(2, activation='softmax')(dropout_layer)

# modelimizin girişlerini ve çıkışlarını ayarlıyoruz
model = Model(inputs=[base_model1.input, base_model2.input], outputs=output_layer)
import tensorflow as tf
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) #lr=0.001 , 0.1
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# shufflenet_input_8 (InputLayer) [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# shufflenet_conv1 (Conv2D)       (None, 112, 112, 24) 648         shufflenet_input_8[0][0]
# __________________________________________________________________________________________________
# shufflenet_maxpool1 (MaxPooling (None, 56, 56, 24)   0           shufflenet_conv1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/1x1_gc (None, 56, 56, 36)   864         shufflenet_maxpool1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/bn_gco (None, 56, 56, 36)   144         shufflenet_stage2/block1/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/relu_g (None, 56, 56, 36)   0           shufflenet_stage2/block1/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/channe (None, 56, 56, 36)   0           shufflenet_stage2/block1/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/1x1_dw (None, 28, 28, 36)   324         shufflenet_stage2/block1/channel_
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/bn_dwc (None, 28, 28, 36)   144         shufflenet_stage2/block1/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/1x1_gc (None, 28, 28, 120)  4320        shufflenet_stage2/block1/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/bn_gco (None, 28, 28, 120)  480         shufflenet_stage2/block1/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/avg_po (None, 28, 28, 24)   0           shufflenet_maxpool1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/concat (None, 28, 28, 144)  0           shufflenet_stage2/block1/bn_gconv
#                                                                  shufflenet_stage2/block1/avg_pool
# __________________________________________________________________________________________________
# shufflenet_stage2/block1/relu_o (None, 28, 28, 144)  0           shufflenet_stage2/block1/concat[0
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/1x1_gc (None, 28, 28, 36)   5184        shufflenet_stage2/block1/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/bn_gco (None, 28, 28, 36)   144         shufflenet_stage2/block2/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/relu_g (None, 28, 28, 36)   0           shufflenet_stage2/block2/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/channe (None, 28, 28, 36)   0           shufflenet_stage2/block2/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/1x1_dw (None, 28, 28, 36)   324         shufflenet_stage2/block2/channel_
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/bn_dwc (None, 28, 28, 36)   144         shufflenet_stage2/block2/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/1x1_gc (None, 28, 28, 144)  5184        shufflenet_stage2/block2/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/bn_gco (None, 28, 28, 144)  576         shufflenet_stage2/block2/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/add (A (None, 28, 28, 144)  0           shufflenet_stage2/block2/bn_gconv
#                                                                  shufflenet_stage2/block1/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block2/relu_o (None, 28, 28, 144)  0           shufflenet_stage2/block2/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/1x1_gc (None, 28, 28, 36)   5184        shufflenet_stage2/block2/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/bn_gco (None, 28, 28, 36)   144         shufflenet_stage2/block3/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/relu_g (None, 28, 28, 36)   0           shufflenet_stage2/block3/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/channe (None, 28, 28, 36)   0           shufflenet_stage2/block3/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/1x1_dw (None, 28, 28, 36)   324         shufflenet_stage2/block3/channel_
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/bn_dwc (None, 28, 28, 36)   144         shufflenet_stage2/block3/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/1x1_gc (None, 28, 28, 144)  5184        shufflenet_stage2/block3/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/bn_gco (None, 28, 28, 144)  576         shufflenet_stage2/block3/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/add (A (None, 28, 28, 144)  0           shufflenet_stage2/block3/bn_gconv
#                                                                  shufflenet_stage2/block2/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block3/relu_o (None, 28, 28, 144)  0           shufflenet_stage2/block3/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/1x1_gc (None, 28, 28, 36)   5184        shufflenet_stage2/block3/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/bn_gco (None, 28, 28, 36)   144         shufflenet_stage2/block4/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/relu_g (None, 28, 28, 36)   0           shufflenet_stage2/block4/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/channe (None, 28, 28, 36)   0           shufflenet_stage2/block4/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/1x1_dw (None, 28, 28, 36)   324         shufflenet_stage2/block4/channel_
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/bn_dwc (None, 28, 28, 36)   144         shufflenet_stage2/block4/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/1x1_gc (None, 28, 28, 144)  5184        shufflenet_stage2/block4/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/bn_gco (None, 28, 28, 144)  576         shufflenet_stage2/block4/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/add (A (None, 28, 28, 144)  0           shufflenet_stage2/block4/bn_gconv
#                                                                  shufflenet_stage2/block3/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage2/block4/relu_o (None, 28, 28, 144)  0           shufflenet_stage2/block4/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/1x1_gc (None, 28, 28, 72)   10368       shufflenet_stage2/block4/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/bn_gco (None, 28, 28, 72)   288         shufflenet_stage3/block1/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/relu_g (None, 28, 28, 72)   0           shufflenet_stage3/block1/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/channe (None, 28, 28, 72)   0           shufflenet_stage3/block1/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block1/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block1/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/1x1_gc (None, 14, 14, 144)  10368       shufflenet_stage3/block1/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/bn_gco (None, 14, 14, 144)  576         shufflenet_stage3/block1/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/avg_po (None, 14, 14, 144)  0           shufflenet_stage2/block4/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/concat (None, 14, 14, 288)  0           shufflenet_stage3/block1/bn_gconv
#                                                                  shufflenet_stage3/block1/avg_pool
# __________________________________________________________________________________________________
# shufflenet_stage3/block1/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block1/concat[0
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block1/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block2/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block2/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/channe (None, 14, 14, 72)   0           shufflenet_stage3/block2/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block2/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block2/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block2/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block2/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block2/bn_gconv
#                                                                  shufflenet_stage3/block1/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block2/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block2/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block2/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block3/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block3/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/channe (None, 14, 14, 72)   0           shufflenet_stage3/block3/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block3/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block3/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block3/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block3/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block3/bn_gconv
#                                                                  shufflenet_stage3/block2/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block3/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block3/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block3/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block4/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block4/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/channe (None, 14, 14, 72)   0           shufflenet_stage3/block4/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block4/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block4/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block4/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block4/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block4/bn_gconv
#                                                                  shufflenet_stage3/block3/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block4/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block4/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block4/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block5/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block5/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/channe (None, 14, 14, 72)   0           shufflenet_stage3/block5/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block5/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block5/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block5/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block5/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block5/bn_gconv
#                                                                  shufflenet_stage3/block4/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block5/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block5/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block5/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block6/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block6/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/channe (None, 14, 14, 72)   0           shufflenet_stage3/block6/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block6/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block6/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block6/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block6/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block6/bn_gconv
#                                                                  shufflenet_stage3/block5/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block6/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block6/add[0][0
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block6/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block7/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block7/bn_gconv
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/channe (None, 14, 14, 72)   0           shufflenet_stage3/block7/relu_gco
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block7/channel_
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block7/1x1_dwco
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block7/bn_dwcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block7/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block7/bn_gconv
#                                                                  shufflenet_stage3/block6/relu_out
# __________________________________________________________________________________________________
# shufflenet_stage3/block7/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block7/add[0][0
# __________________________________________________________________________________________________
# squeezenet_input_7 (InputLayer) [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/1x1_gc (None, 14, 14, 72)   20736       shufflenet_stage3/block7/relu_out
# __________________________________________________________________________________________________
# squeezenet_conv1 (Conv2D)       (None, 111, 111, 64) 1792        squeezenet_input_7[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/bn_gco (None, 14, 14, 72)   288         shufflenet_stage3/block8/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_relu_conv1 (Activati (None, 111, 111, 64) 0           squeezenet_conv1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/relu_g (None, 14, 14, 72)   0           shufflenet_stage3/block8/bn_gconv
# __________________________________________________________________________________________________
# squeezenet_pool1 (MaxPooling2D) (None, 55, 55, 64)   0           squeezenet_relu_conv1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/channe (None, 14, 14, 72)   0           shufflenet_stage3/block8/relu_gco
# __________________________________________________________________________________________________
# squeezenet_fire2/squeeze1x1 (Co (None, 55, 55, 16)   1040        squeezenet_pool1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/1x1_dw (None, 14, 14, 72)   648         shufflenet_stage3/block8/channel_
# __________________________________________________________________________________________________
# squeezenet_fire2/relu_squeeze1x (None, 55, 55, 16)   0           squeezenet_fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/bn_dwc (None, 14, 14, 72)   288         shufflenet_stage3/block8/1x1_dwco
# __________________________________________________________________________________________________
# squeezenet_fire2/expand1x1 (Con (None, 55, 55, 64)   1088        squeezenet_fire2/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire2/expand3x3 (Con (None, 55, 55, 64)   9280        squeezenet_fire2/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/1x1_gc (None, 14, 14, 288)  20736       shufflenet_stage3/block8/bn_dwcon
# __________________________________________________________________________________________________
# squeezenet_fire2/relu_expand1x1 (None, 55, 55, 64)   0           squeezenet_fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire2/relu_expand3x3 (None, 55, 55, 64)   0           squeezenet_fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/bn_gco (None, 14, 14, 288)  1152        shufflenet_stage3/block8/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire2/concat (Concat (None, 55, 55, 128)  0           squeezenet_fire2/relu_expand1x1[0
#                                                                  squeezenet_fire2/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/add (A (None, 14, 14, 288)  0           shufflenet_stage3/block8/bn_gconv
#                                                                  shufflenet_stage3/block7/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire3/squeeze1x1 (Co (None, 55, 55, 16)   2064        squeezenet_fire2/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage3/block8/relu_o (None, 14, 14, 288)  0           shufflenet_stage3/block8/add[0][0
# __________________________________________________________________________________________________
# squeezenet_fire3/relu_squeeze1x (None, 55, 55, 16)   0           squeezenet_fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/1x1_gc (None, 14, 14, 144)  41472       shufflenet_stage3/block8/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire3/expand1x1 (Con (None, 55, 55, 64)   1088        squeezenet_fire3/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire3/expand3x3 (Con (None, 55, 55, 64)   9280        squeezenet_fire3/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/bn_gco (None, 14, 14, 144)  576         shufflenet_stage4/block1/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire3/relu_expand1x1 (None, 55, 55, 64)   0           squeezenet_fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire3/relu_expand3x3 (None, 55, 55, 64)   0           squeezenet_fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/relu_g (None, 14, 14, 144)  0           shufflenet_stage4/block1/bn_gconv
# __________________________________________________________________________________________________
# squeezenet_fire3/concat (Concat (None, 55, 55, 128)  0           squeezenet_fire3/relu_expand1x1[0
#                                                                  squeezenet_fire3/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/channe (None, 14, 14, 144)  0           shufflenet_stage4/block1/relu_gco
# __________________________________________________________________________________________________
# squeezenet_pool3 (MaxPooling2D) (None, 27, 27, 128)  0           squeezenet_fire3/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/1x1_dw (None, 7, 7, 144)    1296        shufflenet_stage4/block1/channel_
# __________________________________________________________________________________________________
# squeezenet_fire4/squeeze1x1 (Co (None, 27, 27, 32)   4128        squeezenet_pool3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/bn_dwc (None, 7, 7, 144)    576         shufflenet_stage4/block1/1x1_dwco
# __________________________________________________________________________________________________
# squeezenet_fire4/relu_squeeze1x (None, 27, 27, 32)   0           squeezenet_fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/1x1_gc (None, 7, 7, 288)    41472       shufflenet_stage4/block1/bn_dwcon
# __________________________________________________________________________________________________
# squeezenet_fire4/expand1x1 (Con (None, 27, 27, 128)  4224        squeezenet_fire4/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire4/expand3x3 (Con (None, 27, 27, 128)  36992       squeezenet_fire4/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/bn_gco (None, 7, 7, 288)    1152        shufflenet_stage4/block1/1x1_gcon
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/avg_po (None, 7, 7, 288)    0           shufflenet_stage3/block8/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire4/relu_expand1x1 (None, 27, 27, 128)  0           squeezenet_fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire4/relu_expand3x3 (None, 27, 27, 128)  0           squeezenet_fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/concat (None, 7, 7, 576)    0           shufflenet_stage4/block1/bn_gconv
#                                                                  shufflenet_stage4/block1/avg_pool
# __________________________________________________________________________________________________
# squeezenet_fire4/concat (Concat (None, 27, 27, 256)  0           squeezenet_fire4/relu_expand1x1[0
#                                                                  squeezenet_fire4/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block1/relu_o (None, 7, 7, 576)    0           shufflenet_stage4/block1/concat[0
# __________________________________________________________________________________________________
# squeezenet_fire5/squeeze1x1 (Co (None, 27, 27, 32)   8224        squeezenet_fire4/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/1x1_gc (None, 7, 7, 144)    82944       shufflenet_stage4/block1/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire5/relu_squeeze1x (None, 27, 27, 32)   0           squeezenet_fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/bn_gco (None, 7, 7, 144)    576         shufflenet_stage4/block2/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire5/expand1x1 (Con (None, 27, 27, 128)  4224        squeezenet_fire5/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire5/expand3x3 (Con (None, 27, 27, 128)  36992       squeezenet_fire5/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/relu_g (None, 7, 7, 144)    0           shufflenet_stage4/block2/bn_gconv
# __________________________________________________________________________________________________
# squeezenet_fire5/relu_expand1x1 (None, 27, 27, 128)  0           squeezenet_fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire5/relu_expand3x3 (None, 27, 27, 128)  0           squeezenet_fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/channe (None, 7, 7, 144)    0           shufflenet_stage4/block2/relu_gco
# __________________________________________________________________________________________________
# squeezenet_fire5/concat (Concat (None, 27, 27, 256)  0           squeezenet_fire5/relu_expand1x1[0
#                                                                  squeezenet_fire5/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/1x1_dw (None, 7, 7, 144)    1296        shufflenet_stage4/block2/channel_
# __________________________________________________________________________________________________
# squeezenet_pool5 (MaxPooling2D) (None, 13, 13, 256)  0           squeezenet_fire5/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/bn_dwc (None, 7, 7, 144)    576         shufflenet_stage4/block2/1x1_dwco
# __________________________________________________________________________________________________
# squeezenet_fire6/squeeze1x1 (Co (None, 13, 13, 48)   12336       squeezenet_pool5[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/1x1_gc (None, 7, 7, 576)    82944       shufflenet_stage4/block2/bn_dwcon
# __________________________________________________________________________________________________
# squeezenet_fire6/relu_squeeze1x (None, 13, 13, 48)   0           squeezenet_fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/bn_gco (None, 7, 7, 576)    2304        shufflenet_stage4/block2/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire6/expand1x1 (Con (None, 13, 13, 192)  9408        squeezenet_fire6/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire6/expand3x3 (Con (None, 13, 13, 192)  83136       squeezenet_fire6/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/add (A (None, 7, 7, 576)    0           shufflenet_stage4/block2/bn_gconv
#                                                                  shufflenet_stage4/block1/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire6/relu_expand1x1 (None, 13, 13, 192)  0           squeezenet_fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire6/relu_expand3x3 (None, 13, 13, 192)  0           squeezenet_fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block2/relu_o (None, 7, 7, 576)    0           shufflenet_stage4/block2/add[0][0
# __________________________________________________________________________________________________
# squeezenet_fire6/concat (Concat (None, 13, 13, 384)  0           squeezenet_fire6/relu_expand1x1[0
#                                                                  squeezenet_fire6/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/1x1_gc (None, 7, 7, 144)    82944       shufflenet_stage4/block2/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire7/squeeze1x1 (Co (None, 13, 13, 48)   18480       squeezenet_fire6/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/bn_gco (None, 7, 7, 144)    576         shufflenet_stage4/block3/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire7/relu_squeeze1x (None, 13, 13, 48)   0           squeezenet_fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/relu_g (None, 7, 7, 144)    0           shufflenet_stage4/block3/bn_gconv
# __________________________________________________________________________________________________
# squeezenet_fire7/expand1x1 (Con (None, 13, 13, 192)  9408        squeezenet_fire7/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire7/expand3x3 (Con (None, 13, 13, 192)  83136       squeezenet_fire7/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/channe (None, 7, 7, 144)    0           shufflenet_stage4/block3/relu_gco
# __________________________________________________________________________________________________
# squeezenet_fire7/relu_expand1x1 (None, 13, 13, 192)  0           squeezenet_fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire7/relu_expand3x3 (None, 13, 13, 192)  0           squeezenet_fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/1x1_dw (None, 7, 7, 144)    1296        shufflenet_stage4/block3/channel_
# __________________________________________________________________________________________________
# squeezenet_fire7/concat (Concat (None, 13, 13, 384)  0           squeezenet_fire7/relu_expand1x1[0
#                                                                  squeezenet_fire7/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/bn_dwc (None, 7, 7, 144)    576         shufflenet_stage4/block3/1x1_dwco
# __________________________________________________________________________________________________
# squeezenet_fire8/squeeze1x1 (Co (None, 13, 13, 64)   24640       squeezenet_fire7/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/1x1_gc (None, 7, 7, 576)    82944       shufflenet_stage4/block3/bn_dwcon
# __________________________________________________________________________________________________
# squeezenet_fire8/relu_squeeze1x (None, 13, 13, 64)   0           squeezenet_fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/bn_gco (None, 7, 7, 576)    2304        shufflenet_stage4/block3/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire8/expand1x1 (Con (None, 13, 13, 256)  16640       squeezenet_fire8/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire8/expand3x3 (Con (None, 13, 13, 256)  147712      squeezenet_fire8/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/add (A (None, 7, 7, 576)    0           shufflenet_stage4/block3/bn_gconv
#                                                                  shufflenet_stage4/block2/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire8/relu_expand1x1 (None, 13, 13, 256)  0           squeezenet_fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire8/relu_expand3x3 (None, 13, 13, 256)  0           squeezenet_fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block3/relu_o (None, 7, 7, 576)    0           shufflenet_stage4/block3/add[0][0
# __________________________________________________________________________________________________
# squeezenet_fire8/concat (Concat (None, 13, 13, 512)  0           squeezenet_fire8/relu_expand1x1[0
#                                                                  squeezenet_fire8/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/1x1_gc (None, 7, 7, 144)    82944       shufflenet_stage4/block3/relu_out
# __________________________________________________________________________________________________
# squeezenet_fire9/squeeze1x1 (Co (None, 13, 13, 64)   32832       squeezenet_fire8/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/bn_gco (None, 7, 7, 144)    576         shufflenet_stage4/block4/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_fire9/relu_squeeze1x (None, 13, 13, 64)   0           squeezenet_fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/relu_g (None, 7, 7, 144)    0           shufflenet_stage4/block4/bn_gconv
# __________________________________________________________________________________________________
# squeezenet_fire9/expand1x1 (Con (None, 13, 13, 256)  16640       squeezenet_fire9/relu_squeeze1x1[
# __________________________________________________________________________________________________
# squeezenet_fire9/expand3x3 (Con (None, 13, 13, 256)  147712      squeezenet_fire9/relu_squeeze1x1[
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/channe (None, 7, 7, 144)    0           shufflenet_stage4/block4/relu_gco
# __________________________________________________________________________________________________
# squeezenet_fire9/relu_expand1x1 (None, 13, 13, 256)  0           squeezenet_fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# squeezenet_fire9/relu_expand3x3 (None, 13, 13, 256)  0           squeezenet_fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/1x1_dw (None, 7, 7, 144)    1296        shufflenet_stage4/block4/channel_
# __________________________________________________________________________________________________
# squeezenet_fire9/concat (Concat (None, 13, 13, 512)  0           squeezenet_fire9/relu_expand1x1[0
#                                                                  squeezenet_fire9/relu_expand3x3[0
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/bn_dwc (None, 7, 7, 144)    576         shufflenet_stage4/block4/1x1_dwco
# __________________________________________________________________________________________________
# squeezenet_drop9 (Dropout)      (None, 13, 13, 512)  0           squeezenet_fire9/concat[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/1x1_gc (None, 7, 7, 576)    82944       shufflenet_stage4/block4/bn_dwcon
# __________________________________________________________________________________________________
# squeezenet_conv10 (Conv2D)      (None, 13, 13, 1000) 513000      squeezenet_drop9[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/bn_gco (None, 7, 7, 576)    2304        shufflenet_stage4/block4/1x1_gcon
# __________________________________________________________________________________________________
# squeezenet_relu_conv10 (Activat (None, 13, 13, 1000) 0           squeezenet_conv10[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/add (A (None, 7, 7, 576)    0           shufflenet_stage4/block4/bn_gconv
#                                                                  shufflenet_stage4/block3/relu_out
# __________________________________________________________________________________________________
# squeezenet_global_average_pooli (None, 1000)         0           squeezenet_relu_conv10[0][0]
# __________________________________________________________________________________________________
# shufflenet_stage4/block4/relu_o (None, 7, 7, 576)    0           shufflenet_stage4/block4/add[0][0
# __________________________________________________________________________________________________
# squeezenet_loss (Activation)    (None, 1000)         0           squeezenet_global_average_pooling
# __________________________________________________________________________________________________
# shufflenet_global_pool (GlobalM (None, 576)          0           shufflenet_stage4/block4/relu_out
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1576)         0           squeezenet_loss[0][0]
#                                                                  shufflenet_global_pool[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1576)         0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1576)         0           flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            3154        dropout_3[0][0]
# ==================================================================================================
# Total params: 2,208,178
# Trainable params: 2,193,538
# Non-trainable params: 14,640
# __________________________________________________________________________________________________

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.3, random_state=SEED)

# %%
EPOCHS = 50#50
BATCH_SIZE= 32 #64

hist_concat = model.fit([X_train,X_train], Y_train,
                        batch_size = BATCH_SIZE,
                shuffle=True, #burada her epoch öncesinde bir karıştırma yaparak overfitting in önüne geçmeye çalışıyoruz
               epochs=EPOCHS,
               verbose=1,
               validation_data=([X_val, X_val], Y_val))
# Out:
# Epoch 1/50
# 38/38 [==============================] - 25s 667ms/step - loss: 4.8526 - accuracy: 0.5125 - val_loss: 0.6886 - val_accuracy: 0.5419
# Epoch 2/50
# 38/38 [==============================] - 25s 647ms/step - loss: 4.1710 - accuracy: 0.5084 - val_loss: 0.6892 - val_accuracy: 0.5419
# Epoch 3/50
# 38/38 [==============================] - 24s 641ms/step - loss: 2.9136 - accuracy: 0.5293 - val_loss: 0.6913 - val_accuracy: 0.5439
# Epoch 4/50
# 38/38 [==============================] - 25s 649ms/step - loss: 2.4395 - accuracy: 0.5217 - val_loss: 0.6893 - val_accuracy: 0.5419
# Epoch 5/50
# 38/38 [==============================] - 24s 640ms/step - loss: 1.9565 - accuracy: 0.5184 - val_loss: 0.6893 - val_accuracy: 0.5419
# Epoch 6/50
# 38/38 [==============================] - 24s 643ms/step - loss: 1.4590 - accuracy: 0.5401 - val_loss: 0.6902 - val_accuracy: 0.5419
# Epoch 7/50
# 38/38 [==============================] - 24s 643ms/step - loss: 1.2585 - accuracy: 0.5376 - val_loss: 0.6895 - val_accuracy: 0.5419
# Epoch 8/50
# 38/38 [==============================] - 24s 644ms/step - loss: 1.0088 - accuracy: 0.5552 - val_loss: 0.6906 - val_accuracy: 0.5419
# Epoch 9/50
# 38/38 [==============================] - 24s 642ms/step - loss: 1.0701 - accuracy: 0.5192 - val_loss: 0.6986 - val_accuracy: 0.5419
# Epoch 10/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.9999 - accuracy: 0.5201 - val_loss: 0.7131 - val_accuracy: 0.4581
# Epoch 11/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.9406 - accuracy: 0.5226 - val_loss: 0.6957 - val_accuracy: 0.4639
# Epoch 12/50
# 38/38 [==============================] - 25s 657ms/step - loss: 0.9036 - accuracy: 0.5268 - val_loss: 0.6910 - val_accuracy: 0.5458
# Epoch 13/50
# 38/38 [==============================] - 26s 674ms/step - loss: 0.9430 - accuracy: 0.5452 - val_loss: 0.8478 - val_accuracy: 0.5419
# Epoch 14/50
# 38/38 [==============================] - 25s 650ms/step - loss: 0.9199 - accuracy: 0.5360 - val_loss: 0.6868 - val_accuracy: 0.5497
# Epoch 15/50
# 38/38 [==============================] - 25s 667ms/step - loss: 0.8846 - accuracy: 0.5360 - val_loss: 0.7994 - val_accuracy: 0.4581
# Epoch 16/50
# 38/38 [==============================] - 26s 685ms/step - loss: 0.8437 - accuracy: 0.5936 - val_loss: 0.6821 - val_accuracy: 0.5770
# Epoch 17/50
# 38/38 [==============================] - 26s 676ms/step - loss: 0.8520 - accuracy: 0.5385 - val_loss: 0.6979 - val_accuracy: 0.5244
# Epoch 18/50
# 38/38 [==============================] - 25s 662ms/step - loss: 0.8085 - accuracy: 0.5585 - val_loss: 0.6909 - val_accuracy: 0.5575
# Epoch 19/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.8577 - accuracy: 0.5510 - val_loss: 0.6890 - val_accuracy: 0.5478
# Epoch 20/50
# 38/38 [==============================] - 25s 645ms/step - loss: 0.8310 - accuracy: 0.5761 - val_loss: 0.8742 - val_accuracy: 0.5419
# Epoch 21/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.8465 - accuracy: 0.5786 - val_loss: 0.7345 - val_accuracy: 0.5595
# Epoch 22/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.8167 - accuracy: 0.6171 - val_loss: 0.7473 - val_accuracy: 0.5458
# Epoch 23/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.7499 - accuracy: 0.6446 - val_loss: 0.9011 - val_accuracy: 0.5497
# Epoch 24/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.6984 - accuracy: 0.6848 - val_loss: 1.2489 - val_accuracy: 0.5848
# Epoch 25/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.6186 - accuracy: 0.7324 - val_loss: 4.4066 - val_accuracy: 0.4620
# Epoch 26/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.6510 - accuracy: 0.7467 - val_loss: 1.8187 - val_accuracy: 0.4873
# Epoch 27/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.5832 - accuracy: 0.7559 - val_loss: 4.2354 - val_accuracy: 0.4717
# Epoch 28/50
# 38/38 [==============================] - 25s 647ms/step - loss: 0.4347 - accuracy: 0.8018 - val_loss: 1.7654 - val_accuracy: 0.4971
# Epoch 29/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.5443 - accuracy: 0.7935 - val_loss: 1.5611 - val_accuracy: 0.4990
# Epoch 30/50
# 38/38 [==============================] - 25s 645ms/step - loss: 0.4967 - accuracy: 0.7726 - val_loss: 1.9765 - val_accuracy: 0.4951
# Epoch 31/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.3010 - accuracy: 0.8813 - val_loss: 2.4746 - val_accuracy: 0.5283
# Epoch 32/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.2686 - accuracy: 0.8963 - val_loss: 2.4700 - val_accuracy: 0.5146
# Epoch 33/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.3722 - accuracy: 0.8537 - val_loss: 3.0103 - val_accuracy: 0.4776
# Epoch 34/50
# 38/38 [==============================] - 25s 647ms/step - loss: 0.3976 - accuracy: 0.8537 - val_loss: 3.1364 - val_accuracy: 0.4873
# Epoch 35/50
# 38/38 [==============================] - 26s 686ms/step - loss: 0.3376 - accuracy: 0.8637 - val_loss: 2.5701 - val_accuracy: 0.4776
# Epoch 36/50
# 38/38 [==============================] - 26s 697ms/step - loss: 0.4070 - accuracy: 0.8420 - val_loss: 2.5785 - val_accuracy: 0.5244
# Epoch 37/50
# 38/38 [==============================] - 26s 676ms/step - loss: 0.2491 - accuracy: 0.9030 - val_loss: 1.8692 - val_accuracy: 0.5439
# Epoch 38/50
# 38/38 [==============================] - 25s 653ms/step - loss: 0.1718 - accuracy: 0.9314 - val_loss: 2.5430 - val_accuracy: 0.5049
# Epoch 39/50
# 38/38 [==============================] - 25s 663ms/step - loss: 0.1865 - accuracy: 0.9314 - val_loss: 2.3250 - val_accuracy: 0.5283
# Epoch 40/50
# 38/38 [==============================] - 25s 655ms/step - loss: 0.2010 - accuracy: 0.9281 - val_loss: 2.3595 - val_accuracy: 0.5653
# Epoch 41/50
# 38/38 [==============================] - 25s 650ms/step - loss: 0.2371 - accuracy: 0.9147 - val_loss: 2.2174 - val_accuracy: 0.5166
# Epoch 42/50
# 38/38 [==============================] - 25s 646ms/step - loss: 0.4596 - accuracy: 0.8704 - val_loss: 2.0762 - val_accuracy: 0.5380
# Epoch 43/50
# 38/38 [==============================] - 25s 645ms/step - loss: 0.3243 - accuracy: 0.8771 - val_loss: 1.7556 - val_accuracy: 0.5556
# Epoch 44/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.3059 - accuracy: 0.8930 - val_loss: 2.3176 - val_accuracy: 0.4912
# Epoch 45/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.1963 - accuracy: 0.9264 - val_loss: 3.2019 - val_accuracy: 0.4561
# Epoch 46/50
# 38/38 [==============================] - 25s 651ms/step - loss: 0.1292 - accuracy: 0.9482 - val_loss: 4.9528 - val_accuracy: 0.4581
# Epoch 47/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.1487 - accuracy: 0.9423 - val_loss: 3.1315 - val_accuracy: 0.4854
# Epoch 48/50
# 38/38 [==============================] - 25s 649ms/step - loss: 0.2800 - accuracy: 0.9038 - val_loss: 2.1399 - val_accuracy: 0.5380
# Epoch 49/50
# 38/38 [==============================] - 25s 645ms/step - loss: 0.2618 - accuracy: 0.8980 - val_loss: 1.8445 - val_accuracy: 0.5244
# Epoch 50/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.1487 - accuracy: 0.9348 - val_loss: 2.0573 - val_accuracy: 0.5517

# %%
y_pred = model.predict([X_val, X_val])
y_pred=np.argmax(y_pred , axis =1).reshape(-1,1)
Y_val=np.argmax(Y_val, axis =1).reshape(-1,1)

print(" MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred, average='macro'))
print("Hassasiyet: ",precision_score(Y_val, y_pred, average='macro'))
print("Duyarlılık: ", recall_score(Y_val, y_pred, average='macro'))


plt.plot(hist_concat.history['accuracy'])
plt.plot(hist_concat.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist_concat.history['loss'])
plt.plot(hist_concat.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix ResNet50v2+IncResnetV2')
cm_dense = confusion_matrix(Y_val, y_pred)
print(cm_dense)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm_dense, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
#  MODEL SONUÇLARI
# Doğruluk:  0.5516569200779727
# F1_Skor:  0.5429011963057088
# Hassasiyet:  0.5452543336175051
# Duyarlılık:  0.5438772386346242
# Confusion Matrix ResNet50v2+IncResnetV2
# [[177 101]
#  [129 106]]
# <AxesSubplot:>
